# %% [markdown]
# # Feature Engineering

# %% [markdown]
# This section will cover the following types of features for the Yelp reviews:
#
# 1.  Bag of Words
#
# 2.  Bag of N-Grams
#
# 3.  TF-IDF (term frequency over inverse document frequency)

# %%
import pandas as pd
import numpy as np
import re
import nltk

# %% [markdown]
# The corpus or the reviews were extracted from the Yelp review dataset using pandas

# %%
corpus_df = pd.read_csv('subset.csv')
corpus = corpus_df['text']
corpus.head()
# Out:
# 0    Hallelujah! I FINALLY FOUND IT! The frozen yog...
# 1    I drop by BnC on a weekly basis to pick up my ...
# 2    My personally experience here wasn't the best,...
# 3    37 °C = 98.6°F\r\nKoreatown establisments disp...
# 4    My husband & I visited Toronto from the U.S. f...
# Name: text, dtype: object

# %% [markdown]
# # Text pre-processing

# %% [markdown]
# As part of Text pre-processing we removed the special characters, whitespaces and numbers and, converted all the text to
# lower case.

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I)
    # doc = re.sub(r'[^a-zA-Z0-9\s]', '', doc, re.I)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    doc = ''.join(i for i in doc if not i.isdigit())
    return doc

normalize_corpus = np.vectorize(normalize_document)

# %%
norm_corpus = normalize_corpus(corpus)

# %% [markdown]
# # 1.  Bag of Words Model

# %% [markdown]
# We created the Bag of Words model to determine the unique words in each document along with its value

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(min_df=0., max_df=1.)
cv_matrix = cv.fit_transform(norm_corpus)
# cv_matrix = cv_matrix.toarray()

# %% [markdown]
# Thus you can see that our documents have been converted into numeric vectors such that each document is represented by one vector (row) in the above feature matrix. The following code will help represent this in a more easy to understand format.

# %%
# get all unique words in the corpus
vocab = cv.get_feature_names()
vocab
# Out:
# ['__',
#  '___',
#  '____',
#  '_____',
#  '______',
#  '_______',
#  '________',
#  '_________',
#  '__________',
#  '___________',
#  '____________',
#  '_____________',
#  '______________',
#  '_______________',
#  '________________',
#  '_________________',
#  '__________________',
#  '___________________',
#  '____________________',
#  '_____________________',
#  '______________________',
#  '_______________________',
#  '________________________',
#  '_________________________',
#  '__________________________',
#  '___________________________',
#  '____________________________',
#  '_____________________________',
#  '______________________________',
#  '_______________________________',
#  '________________________________',
#  '_________________________________',
#  '__________________________________',
#  '_____________________________________',
#  '_______________________________________',
#  '________________________________________',
#  '__________________________________________',
#  '___________________________________________',
#  '____________________________________________',
#  '______________________________________________',
#  '_______________________________________________',
#  '_________________________________________________',
#  '__________________________________________________',
#  '___________________________________________________',
#  '____________________________________________________',
#  '_____________________________________________________',
#  '______________________________________________________',
#  '_________________________________________________________',
#  '__________________________________________________________',
#  '___________________________________________________________',
#  '_____________________________________________________________',
#  '______________________________________________________________',
#  '_______________________________________________________________',
#  '________________________________________________________________',
#  '_________________________________________________________________',
#  '___________________________________________________________________',
#  '_____________________________________________________________________',
#  '________________________________________________________________________',
#  '__________________________________________________________________________',
#  '_________________________________________________________________________________',
#  '__________________________________________________________________________________',
#  '_________the',
#  '_____atmosphere',
#  '_____food',
#  '_____overall',
#  '_____service',
#  '____the',
#  '___day',
#  '___n',
#  '___when',
#  '__bus',
#  '__lsa',
#  '__ngt__',
#  '__notary',
#  '__o',
#  '__sometypeoffish__',
#  '_a',
#  '_ages_',
#  '_all',
#  '_anderson',
#  '_any_',
#  '_are_',
#  '_bad_',
#  '_barely_',
#  '_big_',
#  '_box_',
#  '_c',
#  '_ca',
#  '_ce',
#  '_cheap_',
#  '_cheese',
#  '_chooses_',
#  '_consistently_',
#  '_cq',
#  '_dargs',
#  '_data',
#  '_definitely_',
#  '_does_',
#  '_douhua_',
#  '_down_',
#  '_duarte',
#  '_eeff_b',
#  '_eiycbz',
#  '_en',
#  '_excellent_',
#  '_expensive_',
#  '_extremely_',
#  '_fbe',
#  '_felt_',
#  '_feng',
#  '_good_',
#  '_gravy_',
#  '_i',
#  '_i_',
#  '_interesting_',
#  '_is_',
#  '_just_',
#  '_kajananc',
#  '_kings',
#  '_krwakwmt',
#  '_ksklafvkwihygspopa',
#  '_last',
#  '_less_',
#  '_like_',
#  '_long_',
#  '_luudmk',
#  '_mattgranger',
#  '_my_',
#  '_mzdlwm',
#  '_news_and_community',
#  '_nice',
#  '_not_',
#  '_now',
#  '_o',
#  '_of',
#  '_on_',
#  '_only_',
#  '_or_',
#  '_ouzjmtcwrftadfhajq',
#  '_parklawn_rd',
#  '_pear',
#  '_picked',
#  '_places_to_get_filipino',
#  '_proper_',
#  '_qnncmfw',
#  '_quite_',
#  '_r',
#  '_really_',
#  '_restaurant',
#  '_rrbbjlgug',
#  '_second',
#  '_seriously_',
#  '_she_',
#  '_shit',
#  '_shocked_',
#  '_some_',
#  '_ssoirhw',
#  '_steakqueenagain',
#  '_stop',
#  '_terrible_',
#  '_that_',
#  '_the',
#  '_the_',
#  '_the_best_',
#  '_themselves',
#  '_they_',
#  '_think_',
#  '_thinks_',
#  '_tiny_',
#  '_too_',
#  '_tqrhjha',
#  '_ttpeyg',
#  '_twice_',
#  '_unhealthy_',
#  '_unique_',
#  '_us',
#  '_very_',
#  '_was',
#  '_wasn',
#  '_will_',
#  '_without',
#  '_won',
#  '_work_',
#  '_xkcnn',
#  '_years_',
#  '_youtiao_',
#  'a_s',
#  'aa',
#  'aaa',
#  'aaaa',
#  'aaaaa',
#  'aaaaaaa',
#  'aaaaaaaaa',
#  'aaaaaaaaaaaa',
#  'aaaaaaaaaaaaaaaaaaaaaaagesss',
#  'aaaaaaaaaaaaaasking',
#  'aaaaaaaaaaaanddd',
#  'aaaaaaaaaaamazing',
#  'aaaaaaaaamazing',
#  'aaaaaaaaand',
#  'aaaaaaaamazing',
#  'aaaaaaaannnnd',
#  'aaaaaaaas',
#  'aaaaaaah',
#  'aaaaaaahhh',
#  'aaaaaaahhhhh',
#  'aaaaaaalll',
#  'aaaaaaamazing',
#  'aaaaaaand',
#  'aaaaaaarrrrrrgggggg',
#  'aaaaaah',
#  'aaaaaall',
#  'aaaaaallllll',
#  'aaaaaamaaaaaziiiiing',
#  'aaaaaamazing',
#  'aaaaaand',
#  'aaaaaare',
#  'aaaaaaribaaa',
#  'aaaaages',
#  'aaaaah',
#  'aaaaahhh',
#  'aaaaahhhhh',
#  'aaaaahhhhhh',
#  'aaaaahs',
#  'aaaaall',
#  'aaaaalll',
#  'aaaaalllll',
#  'aaaaamaazing',
#  'aaaaamazing',
#  'aaaaammmmaaazzzziiinnnggggg',
#  'aaaaamzzzing',
#  'aaaaand',
#  'aaaaandd',
#  'aaaaannnnd',
#  'aaaaannnndddd',
#  'aaaaanyway',
#  'aaaaarrrrgh',
#  'aaaaat',
#  'aaaaawww',
#  'aaaaddlggyaaaaaaqngfq',
#  'aaaadorable',
#  'aaaages',
#  'aaaaggges',
#  'aaaah',
#  'aaaahh',
#  'aaaahhh',
#  'aaaahhhs',
#  'aaaahing',
#  'aaaahs',
#  'aaaaight',
#  'aaaall',
#  'aaaalll',
#  'aaaallllll',
#  'aaaalways',
#  'aaaamazing',
#  'aaaammmmmaaazing',
#  'aaaand',
#  'aaaannnd',
#  'aaaannndd',
#  'aaaanyhow',
#  'aaaanyway',
#  'aaaare',
#  'aaaarrrggghhh',
#  'aaaarrrrrrrrrggggggggghhh',
#  'aaaas',
#  'aaaasss',
#  'aaaat',
#  'aaaawesome',
#  'aaaazing',
#  'aaac',
#  'aaack',
#  'aaaf',
#  'aaagrills',
#  'aaah',
#  'aaahalalsteaks',
#  'aaahed',
#  'aaahh',
#  'aaahhh',
#  'aaahhhh',
#  'aaahhhhh',
#  'aaahhmazing',
#  'aaahing',
#  'aaaiiight',
#  'aaaj',
#  'aaallll',
#  'aaalright',
#  'aaamazing',
#  'aaammmazzzzzingg',
#  'aaand',
#  'aaannd',
#  'aaannnd',
#  'aaannndd',
#  'aaannyway',
#  'aaanyway',
#  'aaanyways',
#  'aaargh',
#  'aaarrgghhh',
#  'aaarrgh',
#  'aaarrrrrrrr',
#  'aaauuggh',
#  'aaawooga',
#  'aaawww',
#  'aabb',
#  'aabdwfcuyb',
#  'aabout',
#  'aac',
#  'aachar',
#  'aachari',
#  'aack',
#  'aacu',
#  'aadd',
#  'aadvantage',
#  'aafter',
#  'aah',
#  'aaha',
#  'aahed',
#  'aahh',
#  'aahhh',
#  'aahhhh',
#  'aahhhhhhmaazing',
#  'aahhmaazing',
#  'aahhs',
#  'aahing',
#  'aahs',
#  'aahwy',
#  'aai',
#  'aaiden',
#  'aaiiyaaa',
#  'aak',
#  'aakash',
#  'aaked',
#  'aakriti',
#  'aakritis',
#  'aal',
#  'aalitle',
#  'aaliyah',
#  'aalo',
#  'aaloo',
#  'aalwa',
#  'aalways',
#  'aam',
#  'aamaazing',
#  'aamazing',
#  'aamir',
#  'aamlate',
#  'aammaazziinngg',
#  'aammmamaazing',
#  'aammmmaaazing',
#  'aamna',
#  'aamzinnnggggg',
#  'aan',
#  'aanach',
#  'aanch',
#  'aand',
#  'aanddd',
#  'aano',
#  'aanrader',
#  'aap',
#  'aapam',
#  'aardvark',
#  'aargh',
#  'aarif',
#  'aaron',
#  'aaron_eats_',
#  'aarons',
#  'aaroport',
#  'aaround',
#  'aarp',
#  'aarre',
#  'aarrgg',
#  'aarrggh',
#  'aarrgghh',
#  'aarti',
#  'aas',
#  'aash',
#  'aat',
#  'aatendent',
#  'aauce',
#  'aaucy',
#  'aawash',
#  'aawww',
#  'aawwwhhhhssssooooooemmm',
#  'aay',
#  'aaya',
#  'aayy',
#  'aaí',
#  'ab',
#  'aba',
#  'ababa',
#  'ababe',
#  'abacaxi',
#  'aback',
#  'abackk',
#  'abacus',
#  'abadabo',
#  'abadir',
#  'abadirs',
#  'abag',
#  'abah',
#  'abai',
#  'abailable',
#  'abaixo',
#  'abalone',
#  'abalonelive',
#  'abalones',
#  'abandon',
#  'abandoned',
#  'abandonedlooking',
#  'abandoning',
#  'abandonment',
#  'abandonned',
#  'abandons',
#  'abandunce',
#  'abao',
#  'abaricious',
#  'abarkcrombie',
#  'abarth',
#  'abas',
#  'abashedly',
#  'abashiri',
#  'abassi',
#  'abate',
#  'abated',
#  'abatement',
#  'abates',
#  'abattage',
#  'abattoir',
#  'abawi',
#  'abb',
#  'abba',
#  'abbaba',
#  'abbabiatta',
#  'abbamania',
#  'abbas',
#  'abbasi',
#  'abbass',
#  'abbasy',
#  'abbatoir',
#  'abbaye',
#  'abbazia',
#  'abbeakndbhb_ihlxqchaq',
#  'abberation',
#  'abbey',
#  'abbeygrand',
#  'abbeys',
#  'abbeyskitchen',
#  'abbi',
#  'abbiamo',
#  'abbirami',
#  'abble',
#  'abbot',
#  'abbots',
#  'abbotsford',
#  'abbott',
#  'abbottking',
#  'abboud',
#  'abbout',
#  'abbrasive',
#  'abbreviate',
#  'abbreviated',
#  'abbreviation',
#  'abbreviations',
#  'abbriterti',
#  'abbruo',
#  'abbruzo',
#  'abbruzzino',
#  'abbruzzos',
#  'abburi',
#  'abburri',
#  'abby',
#  'abc',
#  'abcd',
#  'abcdefghijk',
#  'abcess',
#  'abck',
#  'abcoasters',
#  'abcs',
#  'abd',
#  'abdel',
#  'abderrahman',
#  'abdest',
#  'abdeuklfsxxogxgpig',
#  'abdicate',
#  'abdicated',
#  'abdicating',
#  'abdin',
#  'abdo',
#  'abdolute',
#  'abdomen',
#  'abdomin',
#  'abdominal',
#  'abdominals',
#  'abdonminal',
#  'abduct',
#  'abducted',
#  'abduction',
#  'abductor',
#  'abdul',
#  'abdula',
#  'abdulaziz',
#  'abdule',
#  'abdulla',
#  'abdullah',
#  'abdullas',
#  'abdundant',
#  'abdurahman',
#  'abe',
#  'abebooks',
#  'abec',
#  'abed',
#  'abedi',
#  'abejas',
#  'abel',
#  'abell',
#  'abelled',
#  'abenaro',
#  'abend',
#  'abende',
#  'abendessen',
#  'abends',
#  'abendsonne',
#  'abendveranstaltungen',
#  'aber',
#  'aberage',
#  'aberation',
#  'abercombie',
#  'abercrombie',
#  'aberdeen',
#  'aberino',
#  'aberrant',
#  'aberration',
#  'aberrations',
#  'aberta',
#  'abesent',
#  'abet',
#  'abeurk',
#  'abex',
#  'abexp',
#  'abeyance',
#  'abf',
#  'abfab',
#  'abfahrt',
#  'abfertiung',
#  'abflug',
#  'abgedeckt',
#  'abgefllt',
#  'abgelegte',
#  'abgepackte',
#  'abgesehen',
#  'abgetrennten',
#  'abgewohnt',
#  'abgoosht',
#  'abgosht',
#  'abhi',
#  'abhishek',
#  'abholung',
#  'abhor',
#  'abhore',
#  'abhorently',
#  'abhorration',
#  'abhorred',
#  'abhorrence',
#  'abhorrent',
#  'abhorrently',
#  'abhorring',
#  'abhors',
#  'abhyangas',
#  'abi',
#  'abiance',
#  'abiayion',
#  'abicurious',
#  'abid',
#  'abidance',
#  'abide',
#  'abided',
#  'abides',
#  'abiding',
#  'abience',
#  'abient',
#  'abig',
#  'abigail',
#  'abiid',
#  'abilites',
#  'abilities',
#  'ability',
#  'abilty',
#  'abiocco',
#  'abir',
#  'abiration',
#  'abismal',
#  'abit',
#  'abiteast',
#  'abitibi',
#  'abiut',
#  'abive',
#  'abject',
#  'abjectly',
#  'abke',
#  'abkrzung',
#  'ablahan',
#  'ablaze',
#  'able',
#  'ablebodied',
#  'abled',
#  'ableism',
#  'ableist',
#  'ables',
#  'ableto',
#  'ableton',
#  'abliged',
#  'abloy',
#  'ablution',
#  'ablutions',
#  'ably',
#  'abm',
#  'abmience',
#  'abms',
#  'abnormal',
#  'abnormalities',
#  'abnormality',
#  'abnormally',
#  'abnormaly',
#  'abnoxious',
#  'aboard',
#  'aboauletly',
#  'abobado',
#  'abobe',
#  'abodabo',
#  'abode',
#  'abodo',
#  'abogado',
#  'abogee',
#  'aboit',
#  'aboiut',
#  'abolished',
#  'abolishing',
#  'abolsute',
#  'abolsutely',
#  'abolutely',
#  'abominable',
#  'abominably',
#  'abominal',
#  'abomination',
#  'abominations',
#  'abomonation',
#  'abondance',
#  'abondante',
#  'abondanza',
#  'abonded',
#  'abonne',
#  'abonnement',
#  'abooking',
#  'abooration',
#  'aboot',
#  'abooth',
#  'abord',
#  'abordable',
#  'abordables',
#  'abore',
#  'aboriginal',
#  'aboriginalinspired',
#  'aboriginally',
#  'aboriginals',
#  'aborio',
#  'abort',
#  'aborted',
#  'aborting',
#  'abortion',
#  'abortions',
#  'abos',
#  'aboslute',
#  'aboslutely',
#  'abosolutely',
#  'abosoluty',
#  'abosultly',
#  'abot',
#  'abott',
#  'abotts',
#  'abotu',
#  'abou',
#  'aboua',
#  'aboue',
#  'abound',
#  'abounded',
#  'abounding',
#  'abounds',
#  'abour',
#  'abousolity',
#  'aboustle',
#  'about',
#  'about_four_seasons',
#  'about_skymiles',
#  'about_us',
#  'abouta',
#  'abouti',
#  'aboutnorth',
#  'abouts',
#  'aboutthe',
#  'aboutus',
#  'aboutwhere',
#  'aboutyourhood',
#  'abouuut',
#  'abouve',
#  'abouy',
#  'above',
#  'aboveall',
#  'aboveandbeyond',
#  'aboveaverage',
#  'aboveaverge',
#  'abovegroud',
#  'aboveground',
#  'abovemediocre',
#  'abovementioned',
#  'abover',
#  'aboves',
#  'aboút',
#  'abput',
#  'abr',
#  'abra',
#  'abracadabra',
#  'abraconyc',
#  'abrading',
#  'abraham',
#  'abrahams',
#  'abram',
#  'abramov',
#  'abramovitch',
#  'abrams',
#  'abrand',
#  'abras',
#  'abrasian',
#  'abrasion',
#  'abrasions',
#  'abrasive',
#  'abrasively',
#  'abrcrombie',
#  'abreast',
#  'abreise',
#  'abreisetag',
#  'abri',
#  'abricot',
#  'abridged',
#  'abrigada',
#  'abrigo',
#  'abriram',
#  'abris',
#  'abrió',
#  'abroad',
#  'abroise',
#  'abrosia',
#  'abrubt',
#  'abrubtly',
#  'abrui',
#  'abrump',
#  'abrupt',
#  'abruption',
#  'abruptly',
#  'abruptness',
#  'abruri',
#  'abrushi',
#  'abrutly',
#  'abruzio',
#  'abruzza',
#  'abruzzese',
#  'abruzzi',
#  'abruzzo',
#  'abruzzo_pizza',
#  'abruzzopizza',
#  'abruzzopizza_flyer_',
#  'abruzzos',
#  'abs',
#  'absaultly',
#  'abscess',
#  'abscessed',
#  'abscesses',
#  'abscond',
#  'absconded',
#  'absence',
#  'absences',
#  'absent',
#  'absente',
#  'absentee',
#  'absentia',
#  'absently',
#  'absentminded',
#  'absentmindedly',
#  'absentmindedness',
#  'absents',
#  'absentvacant',
#  'absewnce',
#  'absi',
#  'absilutely',
#  'absinth',
#  'absinthe',
#  'absinthophile',
#  'absinths',
#  'absintini',
#  'absloutely',
#  'abso',
#  'absofavourite',
#  'absofricking',
#  'absofrickinlutely',
#  'absofuckinglutely',
#  'absolotely',
#  'absolotuley',
#  'absoloute',
#  'absoloutely',
#  'absoloutley',
#  'absoloutly',
#  'absoltely',
#  'absoltuely',
#  'absoluely',
#  'absoluetly',
#  'absoluety',
#  'absolulely',
#  'absolultely',
#  'absolulutely',
#  'absolument',
#  'absolut',
#  'absolute',
#  'absoluteeeee',
#  'absolutele',
#  'absolutelllllyyyy',
#  'absolutelly',
#  'absolutelty',
#  'absolutelu',
#  'absolutely',
#  'absolutelya',
#  'absolutelyloved',
#  'absolutelyyy',
#  'absolutes',
#  'absolutest',
#  'absolutetly',
#  'absolutey',
#  'absolution',
#  'absolutism',
#  'absolutist',
#  'absolutlely',
#  'absolutlety',
#  'absolutley',
#  'absolutly',
#  'absoluty',
#  'absoluuuuuutttteeellly',
#  'absoluyely',
#  'absolve',
#  'absolved',
#  'absolves',
#  'absorb',
#  'absorbancy',
#  'absorbatent',
#  'absorbed',
#  'absorbency',
#  'absorbent',
#  'absorber',
#  'absorbers',
#  'absorbing',
#  'absorbs',
#  'absorbtion',
#  'absorption',
#  'absouitely',
#  'absoulety',
#  'absoultely',
#  'absoultey',
#  'absoultly',
#  'absoulutely',
#  'absoutely',
#  'abssoulti',
#  'abssynia',
#  'abstain',
#  'abstained',
#  'abstaining',
#  'abstains',
#  'abstand',
#  'abstecher',
#  'abstinence',
#  'abstolutely',
#  'abstract',
#  'abstracted',
#  'abstracts',
#  'absulote',
#  'absulutely',
#  'absurb',
#  'absurd',
#  'absurdia',
#  'absurdity',
#  'absurdly',
#  'absymal',
#  'absynthe',
#  'abt',
#  'abtasted',
#  'abtd',
#  'abteer',
#  'abteilen',
#  'abteilungen',
#  'abu',
#  'abudance',
#  'abudnance',
#  'abuela',
#  'abuelas',
#  'abuelita',
#  'abulahea',
#  'abulsute',
#  'abunch',
#  'abundace',
#  'abundance',
#  'abundances',
#  'abundancy',
#  'abundandant',
#  'abundant',
#  'abundante',
#  'abundantly',
#  'abundence',
#  'abundent',
#  'abundunt',
#  'abunga',
#  'abuot',
#  'abura',
#  'aburaage',
#  'aburai',
#  'abure',
#  'aburi',
#  'aburicious',
#  'aburis',
#  'aburiscious',
#  'aburistyle',
#  'aburisushi',
#  'aburitorched',
#  'aburo',
#  'aburri',
#  'aburuchio',
#  'aburusicios',
#  'abus',
#  'abusable',
#  'abuse',
#  'abused',
#  'abuser',
#  'abusers',
#  'abuses',
#  'abusing',
#  'abusive',
#  'abusively',
#  'abusiveness',
#  'abusivo',
#  'abusolutely',
#  'abut',
#  'abuts',
#  'abutted',
#  'abutting',
#  'abuzz',
#  'abv',
#  'abvious',
#  'abviously',
#  'abwandlungen',
#  'abwechlungsreiche',
#  'abwechslung',
#  'abwheel',
#  'abwinken',
#  'aby',
#  'abyone',
#  'abys',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'abyssal',
#  'abyssinia',
#  'abyssinian',
#  'abyssinians',
#  'abyssmal',
#  'abything',
#  'abzug',
#  'ac',
#  'ac_apg',
#  'acabado',
#  'acabamos',
#  'acacado',
#  'acacia',
#  'acacias',
#  'academese',
#  'academia',
#  'academic',
#  'academically',
#  'academics',
#  'academies',
#  'academy',
#  'academyinstitute',
#  'academystudent',
#  'acadey',
#  'acadia',
#  'acadian',
#  'acadians',
#  'acadomy',
#  'acafrao',
#  'acai',
#  'acaibowl',
#  'acaii',
#  'acana',
#  'acanac',
#  'acanacs',
#  'acandfurnace',
#  'acapella',
#  ...]

# %% [markdown]
# # 2.  Bag of N-Grams Model

# %% [markdown]
# We created the Bag of bi-grams and tri-grams to look at the 2-word and 3-word strings used in our corpus.

# %%
bv = CountVectorizer(ngram_range=(2,2))
bv_matrix = bv.fit_transform(norm_corpus)

bv_matrix = np.asarray(bv_matrix)
vocab = bv.get_feature_names()
# pd.DataFrame(bv_matrix, columns=vocab)
vocab
# Out:
# ['__ __',
#  '__ ____',
#  '__ adorned',
#  '__ also',
#  '__ amount',
#  '__ anyways',
#  '__ bavaria',
#  '__ cheap',
#  '__ check',
#  '__ dancing',
#  '__ dine',
#  '__ disappointed',
#  '__ drag',
#  '__ expecting',
#  '__ experience',
#  '__ explained',
#  '__ female',
#  '__ got',
#  '__ hehehe',
#  '__ hip',
#  '__ insert',
#  '__ inventory',
#  '__ lastly',
#  '__ line',
#  '__ lot',
#  '__ lychee',
#  '__ maybe',
#  '__ meat',
#  '__ mushroom',
#  '__ one',
#  '__ patio',
#  '__ pdf',
#  '__ peppers',
#  '__ pita',
#  '__ really',
#  '__ recall',
#  '__ scrambled',
#  '__ service',
#  '__ something',
#  '__ sucker',
#  '__ suffice',
#  '__ sunset',
#  '__ szechuan',
#  '__ tea',
#  '__ thing',
#  '__ tl',
#  '__ top',
#  '__ tough',
#  '__ treat',
#  '__ tried',
#  '__ typically',
#  '__ waitress',
#  '__ went',
#  '__ wish',
#  '__ yes',
#  '___ ___',
#  '___ ____',
#  '___ advised',
#  '___ always',
#  '___ appetizers',
#  '___ asked',
#  '___ big',
#  '___ bird',
#  '___ definitely',
#  '___ desert',
#  '___ dessert',
#  '___ done',
#  '___ drinks',
#  '___ drooool',
#  '___ end',
#  '___ equipment',
#  '___ ever',
#  '___ everyone',
#  '___ free',
#  '___ friend',
#  '___ green',
#  '___ hwy',
#  '___ insert',
#  '___ learned',
#  '___ like',
#  '___ long',
#  '___ made',
#  '___ minutes',
#  '___ names',
#  '___ ordered',
#  '___ overall',
#  '___ paying',
#  '___ pub',
#  '___ right',
#  '___ round',
#  '___ said',
#  '___ server',
#  '___ similar',
#  '___ sport',
#  '___ sure',
#  '___ tori',
#  '___ well',
#  '___ without',
#  '___ would',
#  '____ __',
#  '____ absolutely',
#  '____ according',
#  '____ ahhh',
#  '____ anyway',
#  '____ beef',
#  '____ blocks',
#  '____ board',
#  '____ bother',
#  '____ bun',
#  '____ cheap',
#  '____ comparison',
#  '____ complete',
#  '____ creative',
#  '____ ct',
#  '____ customer',
#  '____ cut',
#  '____ delicious',
#  '____ dr',
#  '____ employee',
#  '____ fill',
#  '____ get',
#  '____ good',
#  '____ incredibly',
#  '____ know',
#  '____ landing',
#  '____ least',
#  '____ lens',
#  '____ like',
#  '____ meat',
#  '____ milk',
#  '____ mine',
#  '____ never',
#  '____ nothin',
#  '____ one',
#  '____ place',
#  '____ preference',
#  '____ problem',
#  '____ quality',
#  '____ ross',
#  '____ seasoned',
#  '____ seriously',
#  '____ server',
#  '____ sorbet',
#  '____ straight',
#  '____ taking',
#  '____ trucks',
#  '____ update',
#  '_____ ___',
#  '_____ _____',
#  '_____ according',
#  '_____ actually',
#  '_____ aka',
#  '_____ beer',
#  '_____ blank',
#  '_____ breakdown',
#  '_____ buying',
#  '_____ cake',
#  '_____ came',
#  '_____ cleaned',
#  '_____ coefficient',
#  '_____ cup',
#  '_____ date',
#  '_____ dsm',
#  '_____ end',
#  '_____ fact',
#  '_____ fine',
#  '_____ first',
#  '_____ françois',
#  '_____ free',
#  '_____ friends',
#  '_____ fun',
#  '_____ geology',
#  '_____ gin',
#  '_____ got',
#  '_____ great',
#  '_____ hear',
#  '_____ imagine',
#  '_____ kidding',
#  '_____ know',
#  '_____ last',
#  '_____ learn',
#  '_____ let',
#  '_____ movie',
#  '_____ none',
#  '_____ opened',
#  '_____ park',
#  '_____ place',
#  '_____ really',
#  '_____ receipt',
#  '_____ ridiculous',
#  '_____ said',
#  '_____ seriously',
#  '_____ stop',
#  '_____ summer',
#  '_____ suppose',
#  '_____ swear',
#  '_____ take',
#  '_____ telling',
#  '_____ unless',
#  '_____ visiting',
#  '_____ witnessed',
#  '_____ would',
#  '_____ yelp',
#  '_____ yelpers',
#  '______ dropped',
#  '______ fair',
#  '______ get',
#  '______ going',
#  '______ last',
#  '______ long',
#  '______ middle',
#  '______ old',
#  '______ poutine',
#  '______ quite',
#  '______ real',
#  '______ soup',
#  '______ sushi',
#  '______ update',
#  '______ vegetable',
#  '______ woman',
#  '_______ affy',
#  '_______ forgot',
#  '_______ hot',
#  '_______ ordered',
#  '_______ reviews',
#  '________ answer',
#  '________ check',
#  '________ inc',
#  '________ insert',
#  '________ mild',
#  '________ really',
#  '________ remember',
#  '_________ event',
#  '_________ flavourwise',
#  '_________ grrr',
#  '_________ http',
#  '_________ vet',
#  '__________ could',
#  '__________ fill',
#  '__________ mentioned',
#  '__________ nobody',
#  '__________ pretty',
#  '__________ price',
#  '__________ update',
#  '___________ average',
#  '___________ karl',
#  '___________ made',
#  '___________ section',
#  '___________ starters',
#  '____________ ______________',
#  '____________ give',
#  '____________ going',
#  '_____________ comparing',
#  '_____________ local',
#  '_____________ may',
#  '_____________ one',
#  '_____________ people',
#  '______________ bet',
#  '______________ decided',
#  '______________ ok',
#  '______________ probably',
#  '______________ wanted',
#  '_______________ civello',
#  '_______________ edit',
#  '_______________ http',
#  '_______________ koreans',
#  '_______________ may',
#  '_______________ second',
#  '_______________ tucked',
#  '________________ another',
#  '________________ cha',
#  '________________ comment',
#  '________________ decor',
#  '________________ go',
#  '________________ hidden',
#  '________________ like',
#  '________________ lovely',
#  '________________ misunderstood',
#  '________________ staff',
#  '_________________ http',
#  '_________________ thanks',
#  '__________________ could',
#  '__________________ friend',
#  '__________________ idea',
#  '__________________ march',
#  '___________________ notes',
#  '___________________ previous',
#  '____________________ baked',
#  '_____________________ pleased',
#  '______________________ funnies',
#  '______________________ pronounced',
#  '______________________ sansotei',
#  '______________________ taxes',
#  '______________________ wait',
#  '_______________________ google',
#  '_______________________ pats',
#  '_______________________ wtf',
#  '________________________ non',
#  '________________________ onto',
#  '_________________________ dear',
#  '_________________________ reservations',
#  '__________________________ topshop',
#  '___________________________ joke',
#  '___________________________ see',
#  '____________________________ favorite',
#  '____________________________ lorex',
#  '____________________________ think',
#  '_____________________________ dumpling',
#  '_____________________________ months',
#  '_____________________________ realistically',
#  '______________________________ location',
#  '______________________________ see',
#  '______________________________ staff',
#  '_______________________________ least',
#  '________________________________ beer',
#  '________________________________ dumb',
#  '________________________________ overall',
#  '________________________________ pool',
#  '________________________________ restrooms',
#  '________________________________ spiderman',
#  '________________________________ starring',
#  '________________________________ table',
#  '________________________________ would',
#  '_________________________________ extra',
#  '_________________________________ omelets',
#  '_________________________________ wearing',
#  '__________________________________ asian',
#  '_____________________________________ also',
#  '_____________________________________ remember',
#  '_______________________________________ dt',
#  '_______________________________________ signature',
#  '_______________________________________ sliced',
#  '________________________________________ alert',
#  '________________________________________ email',
#  '________________________________________ knocked',
#  '________________________________________ tight',
#  '__________________________________________ http',
#  '__________________________________________ tried',
#  '____________________________________________ quick',
#  '______________________________________________ atmosphere',
#  '______________________________________________ service',
#  '_______________________________________________ breaking',
#  '_______________________________________________ sides',
#  '_________________________________________________ authentic',
#  '_________________________________________________ family',
#  '_________________________________________________ going',
#  '__________________________________________________ dishes',
#  '___________________________________________________ love',
#  '___________________________________________________ website',
#  '_____________________________________________________ decided',
#  '_____________________________________________________ original',
#  '______________________________________________________ allergies',
#  '______________________________________________________ appetizer',
#  '______________________________________________________ note',
#  '______________________________________________________ point',
#  '_________________________________________________________ service',
#  '_________________________________________________________ update',
#  '__________________________________________________________ main',
#  '__________________________________________________________ parking',
#  '___________________________________________________________ food',
#  '___________________________________________________________ price',
#  '___________________________________________________________ week',
#  '_____________________________________________________________ drinks',
#  '______________________________________________________________ chiropractor',
#  '______________________________________________________________ decent',
#  '______________________________________________________________ scanty',
#  '______________________________________________________________ service',
#  '______________________________________________________________ summerlicious',
#  '_______________________________________________________________ food',
#  '_______________________________________________________________ salty',
#  '________________________________________________________________ cute',
#  '_________________________________________________________________ back',
#  '_________________________________________________________________ thought',
#  '_________________________________________________________________ update',
#  '___________________________________________________________________ dear',
#  '_____________________________________________________________________ really',
#  '_____________________________________________________________________ update',
#  '________________________________________________________________________ old',
#  '________________________________________________________________________ want',
#  '__________________________________________________________________________ hi',
#  '_________________________________________________________________________________ first',
#  '__________________________________________________________________________________ food',
#  '__________________________________________________________________________________ ridiculous',
#  '_________the food___________',
#  '_____atmosphere place',
#  '_____food food',
#  '_____overall experience',
#  '_____service great',
#  '____the drinks____',
#  '___day remember',
#  '___day would',
#  '___n jpg',
#  '___when family',
#  '__bus driver',
#  '__lsa thanks',
#  '__ngt__ ttdeaddaceaeao_cz',
#  '__notary fees',
#  '__o ___',
#  '__sometypeoffish__ chips',
#  '_a pdf',
#  '_ages_ bring',
#  '_all dishes',
#  '_anderson clean',
#  '_any_ downtown',
#  '_are_ airport',
#  '_are_ eating',
#  '_bad_ definitely',
#  '_barely_ crisp',
#  '_barely_ room',
#  '_big_ mouth',
#  '_box_ six',
#  '_ca accidentally',
#  '_ce jpg',
#  '_cheap_ lot',
#  '_cheese rather',
#  '_chooses_ get',
#  '_consistently_ high',
#  '_cq garage',
#  '_dargs site',
#  '_data photo',
#  '_definitely_ delta',
#  '_does_ pack',
#  '_douhua_ red',
#  '_down_ street',
#  '_duarte get',
#  '_eeff_b jpg',
#  '_eiycbz min',
#  '_en accessories',
#  '_expensive_ ordered',
#  '_extremely_ boozy',
#  '_fbe jpg',
#  '_felt_ greasy',
#  '_feng shui_',
#  '_good_ cannoli',
#  '_good_ thick',
#  '_gravy_ enough',
#  '_i html',
#  '_i_ think',
#  '_interesting_ definitely',
#  '_is_ difference',
#  '_is_ good',
#  '_is_ tasty',
#  '_just_ enough',
#  '_just_ return',
#  '_kings htm',
#  '_krwakwmt noodles',
#  '_krwakwmt upon',
#  '_ksklafvkwihygspopa ryizyeuhmgka',
#  '_last time',
#  '_less_ maple',
#  '_like_ original',
#  '_long_ time',
#  '_mattgranger dining',
#  '_my_ tiny',
#  '_mzdlwm feature',
#  '_news_and_community events',
#  '_nice hotel_',
#  '_not_ us',
#  '_now call',
#  '_o bathrooms',
#  '_o cabbage',
#  '_o called',
#  '_o followed',
#  '_o sushi',
#  '_o went',
#  '_o yikes',
#  '_of despair_',
#  '_on_ table',
#  '_only_ thing',
#  '_or_ landlords',
#  '_ouzjmtcwrftadfhajq gonna',
#  '_pear cider',
#  '_picked off_',
#  '_places_to_get_filipino style_lechon_in_toronto',
#  '_proper_ furniture',
#  '_qnncmfw best',
#  '_quite_ enough',
#  '_r scp',
#  '_really_ friends',
#  '_really_ good',
#  '_really_ like',
#  '_restaurant overview',
#  '_rrbbjlgug karn',
#  '_second time',
#  '_seriously_ uncomfortable',
#  '_she_ chose',
#  '_shit even',
#  '_shocked_ usual',
#  '_some_ authenticity',
#  '_steakqueenagain jpg',
#  '_stop yonge',
#  '_terrible_ one',
#  '_that_ company',
#  '_that_ good',
#  '_the day',
#  '_the place_',
#  '_the shrimp',
#  '_the_ pleasant',
#  '_the_ waxing',
#  '_the_best_ bar',
#  '_themselves sipping',
#  '_they_ made',
#  '_think_ family',
#  '_thinks_ looking',
#  '_tiny_ veggies',
#  '_too_ buttery',
#  '_tqrhjha decided',
#  '_ttpeyg banana',
#  '_twice_ asked',
#  '_unhealthy_ taste',
#  '_unique_ offer',
#  '_us _en',
#  '_very_ fast',
#  '_very_ oily',
#  '_very_ picky',
#  '_very_ spicy',
#  '_was yummy',
#  '_wasn t_',
#  '_will_ turn',
#  '_without looking',
#  '_won t_',
#  '_work_ giving',
#  '_years_ mike',
#  '_youtiao_ always',
#  'a_s rude',
#  'aa ab',
#  'aa aebedbbfde',
#  'aa affiliated',
#  'aa airport',
#  'aa allow',
#  'aa almost',
#  'aa ask',
#  'aa asked',
#  'aa available',
#  'aa bar',
#  'aa batteries',
#  'aa beef',
#  'aa berry',
#  'aa better',
#  'aa blouse',
#  'aa bowls',
#  'aa broke',
#  'aa ca',
#  'aa cabbage',
#  'aa chuck',
#  'aa city',
#  'aa company',
#  'aa completely',
#  'aa confusing',
#  'aa consider',
#  'aa coupled',
#  'aa cups',
#  'aa cx',
#  'aa design',
#  'aa employees',
#  'aa energy',
#  'aa excellent',
#  'aa far',
#  'aa general',
#  'aa gets',
#  'aa glass',
#  'aa grade',
#  'aa greasy',
#  'aa great',
#  'aa grills',
#  'aa hand',
#  'aa higher',
#  'aa juicy',
#  'aa keep',
#  'aa lady',
#  'aa last',
#  'aa least',
#  'aa lier',
#  'aa little',
#  'aa long',
#  'aa lounges',
#  'aa love',
#  'aa manufacturers',
#  'aa marshmallow',
#  'aa meeting',
#  'aa meetings',
#  'aa member',
#  'aa mere',
#  'aa much',
#  'aa near',
#  'aa normal',
#  'aa otherwise',
#  'aa owner',
#  'aa party',
#  'aa perform',
#  'aa plenty',
#  'aa poor',
#  'aa price',
#  'aa pushing',
#  'aa quality',
#  'aa queen',
#  'aa rating',
#  'aa represent',
#  'aa rib',
#  'aa sauce',
#  'aa saw',
#  'aa saying',
#  'aa search',
#  'aa seems',
#  'aa shops',
#  'aa side',
#  'aa sirloin',
#  'aa soon',
#  'aa special',
#  'aa sponsor',
#  'aa staff',
#  'aa starbucks',
#  'aa stores',
#  'aa super',
#  'aa waitress',
#  'aa women',
#  'aa years',
#  'aa yikes',
#  'aaa aaa',
#  'aaa actually',
#  'aaa aged',
#  'aaa alberta',
#  'aaa also',
#  'aaa angus',
#  'aaa another',
#  'aaa anyone',
#  'aaa army',
#  'aaa auto',
#  'aaa average',
#  'aaa awesome',
#  'aaa bar',
#  'aaa become',
#  'aaa beef',
#  'aaa belong',
#  'aaa black',
#  'aaa brisket',
#  'aaa burger',
#  'aaa business',
#  'aaa canadian',
#  'aaa card',
#  'aaa certified',
#  'aaa compared',
#  'aaa continue',
#  'aaa could',
#  'aaa course',
#  'aaa crying',
#  'aaa cuts',
#  'aaa day',
#  'aaa definitely',
#  'aaa delicious',
#  'aaa described',
#  'aaa discount',
#  'aaa discounts',
#  'aaa draft',
#  'aaa dry',
#  'aaa eggs',
#  'aaa even',
#  'aaa expecting',
#  'aaa experience',
#  'aaa fairly',
#  'aaa fantastic',
#  'aaa favours',
#  'aaa filet',
#  'aaa fillet',
#  'aaa filling',
#  'aaa fired',
#  'aaa flat',
#  'aaa food',
#  'aaa four',
#  'aaa fresh',
#  'aaa frozen',
#  'aaa fun',
#  'aaa future',
#  'aaa good',
#  'aaa grade',
#  'aaa grilled',
#  'aaa ground',
#  'aaa guide',
#  'aaa healthy',
#  'aaa hot',
#  'aaa huge',
#  'aaa imo',
#  'aaa included',
#  'aaa job',
#  'aaa know',
#  'aaa make',
#  'aaa mall',
#  'aaa meat',
#  'aaa meats',
#  'aaa medium',
#  'aaa member',
#  'aaa members',
#  'aaa membership',
#  'aaa menu',
#  'aaa michelin',
#  'aaa miss',
#  'aaa movers',
#  'aaa natural',
#  'aaa need',
#  'aaa new',
#  'aaa noted',
#  'aaa number',
#  'aaa ny',
#  'aaa oishi',
#  'aaa ok',
#  'aaa one',
#  'aaa ones',
#  'aaa ontario',
#  'aaa organic',
#  'aaa others',
#  'aaa outright',
#  'aaa oz',
#  'aaa patty',
#  'aaa pepppered',
#  'aaa perfectly',
#  'aaa picanha',
#  'aaa pints',
#  'aaa place',
#  'aaa plain',
#  'aaa plus',
#  'aaa prime',
#  'aaa produce',
#  'aaa pun',
#  'aaa quality',
#  'aaa quite',
#  'aaa rating',
#  'aaa really',
#  'aaa receives',
#  'aaa regardless',
#  'aaa regular',
#  'aaa restaurant',
#  'aaa rib',
#  'aaa ribeye',
#  'aaa ribeyes',
#  'aaa roast',
#  'aaa ruth',
#  'aaa seats',
#  'aaa service',
#  'aaa servicefavorite',
#  'aaa short',
#  'aaa sirloin',
#  'aaa slice',
#  'aaa star',
#  'aaa steak',
#  'aaa steaks',
#  'aaa sterling',
#  'aaa strip',
#  'aaa striploin',
#  'aaa surprised',
#  'aaa tenderloin',
#  'aaa think',
#  'aaa thrifty',
#  'aaa told',
#  'aaa top',
#  'aaa twenty',
#  'aaa well',
#  'aaa wellington',
#  'aaa wildlife',
#  'aaa wine',
#  'aaa worth',
#  'aaa young',
#  'aaaa marble',
#  'aaaaa meat',
#  'aaaaa pluses',
#  'aaaaa yyyyy',
#  'aaaaaaaaa im',
#  'aaaaaaaaa love',
#  'aaaaaaaaaaaa drool',
#  'aaaaaaaaaaaaaaaaaaaaaaagesss outside',
#  'aaaaaaaaaaaaaasking uuuuuuuuuuuuuur',
#  'aaaaaaaaaaaanddd back',
#  'aaaaaaaaaaamazing esp',
#  'aaaaaaaaamazing msg',
#  'aaaaaaaaamazing portions',
#  'aaaaaaaaamazing rainbow',
#  'aaaaaaaaand else',
#  'aaaaaaaaand nearly',
#  'aaaaaaaamazing vegan',
#  'aaaaaaaannnnd confirmed',
#  'aaaaaaaas food',
#  'aaaaaaah going',
#  'aaaaaaahhh beacon',
#  'aaaaaaahhhhh kawa',
#  'aaaaaaand back',
#  'aaaaaaand far',
#  'aaaaaaand service',
#  'aaaaaaarrrrrrgggggg food',
#  'aaaaaah dat',
#  'aaaaaah mazing',
#  'aaaaaall waaay',
#  'aaaaaallllll great',
#  'aaaaaamaaaaaziiiiing celebrated',
#  'aaaaaamazing carnivores',
#  'aaaaaamazing experience',
#  'aaaaaamazing like',
#  'aaaaaamazing shrimp',
#  'aaaaaand actually',
#  'aaaaaand bunch',
#  'aaaaaand maybe',
#  'aaaaaand pumps',
#  'aaaaaand thennnn',
#  'aaaaaand welcome',
#  'aaaaaare aaaat',
#  'aaaaaaribaaa although',
#  'aaaaages worth',
#  'aaaaah asked',
#  'aaaaah came',
#  'aaaaah kill',
#  'aaaaah like',
#  'aaaaahhh town',
#  'aaaaahhhhh best',
#  'aaaaahhhhh go',
#  'aaaaahhhhhh definitely',
#  'aaaaahs verbiage',
#  'aaaaall phooone',
#  'aaaaalll way',
#  'aaaaalllll worth',
#  'aaaaamaazing jamal',
#  'aaaaamazing acupuncture',
#  'aaaaamazing best',
#  'aaaaamazing buttery',
#  'aaaaamazing everything',
#  'aaaaamazing served',
#  'aaaaammmmaaazzzziiinnnggggg everyone',
#  'aaaaamzzzing owners',
#  'aaaaand close',
#  'aaaaand cold',
#  'aaaaand comes',
#  'aaaaand definitely',
#  'aaaaand delicious',
#  'aaaaand everyone',
#  'aaaaand go',
#  'aaaaand going',
#  'aaaaand guy',
#  'aaaaand looked',
#  'aaaaand mostly',
#  'aaaaand water',
#  'aaaaandd need',
#  'aaaaannnnd yes',
#  'aaaaannnndddd spicy',
#  'aaaaanyway annapurna',
#  'aaaaarrrrgh swear',
#  'aaaaat allll',
#  'aaaaawww vanilla',
#  'aaaaddlggyaaaaaaqngfq jpg',
#  'aaaadorable nice',
#  'aaaages ago',
#  'aaaages food',
#  'aaaaggges seriously',
#  'aaaah beauty',
#  'aaaah favour',
#  'aaaah heavenly',
#  'aaaah life',
#  'aaaah overhead',
#  'aaaahh chocolate',
#  'aaaahh different',
#  'aaaahhh came',
#  'aaaahhh laughter',
#  'aaaahhh maze',
#  'aaaahhh pain',
#  'aaaahhh yes',
#  'aaaahhhs party',
#  'aaaahing cars',
#  'aaaahs bring',
#  'aaaaight ive',
#  'aaaall mentioned',
#  'aaaall somehow',
#  'aaaalll way',
#  'aaaallllll oh',
#  'aaaalways packed',
#  'aaaamazing aromatic',
#  'aaaamazing bubble',
#  'aaaamazing crispy',
#  'aaaamazing enough',
#  'aaaamazing freshly',
#  'aaaamazing never',
#  'aaaamazing pita',
#  'aaaamazing smoke',
#  'aaaammmmmaaazing service',
#  'aaaand amazing',
#  'aaaand cheap',
#  'aaaand cheese',
#  'aaaand get',
#  'aaaand great',
#  'aaaand halal',
#  'aaaand lets',
#  'aaaand never',
#  'aaaand popcorn',
#  'aaaand put',
#  'aaaand result',
#  'aaaand ribs',
#  'aaaand saw',
#  'aaaand store',
#  'aaaand tastes',
#  'aaaand wait',
#  'aaaand wine',
#  'aaaand winter',
#  'aaaand yes',
#  'aaaannnd block',
#  'aaaannndd chinese',
#  'aaaanyhow got',
#  'aaaanyway place',
#  'aaaanyway thanks',
#  'aaaare veeery',
#  'aaaarrrggghhh little',
#  'aaaarrrrrrrrrggggggggghhh working',
#  'aaaas delicious',
#  'aaaasss good',
#  'aaaat duuuuu',
#  'aaaawesome mexican',
#  'aaac primus',
#  'aaack install',
#  'aaagrills edible',
#  'aaah celebration',
#  'aaah cold',
#  'aaah delicious',
#  'aaah europe',
#  'aaah flavours',
#  'aaah free',
#  'aaah ing',
#  'aaah maz',
#  'aaah one',
#  'aaah sunday',
#  'aaah tastebuds',
#  'aaah yes',
#  'aaahalalsteaks com',
#  'aaahed buy',
#  'aaahh best',
#  'aaahh good',
#  'aaahhh heavenly',
#  'aaahhh know',
#  'aaahhh start',
#  'aaahhhh around',
#  'aaahhhh brilliant',
#  'aaahhhh potatoes',
#  'aaahhhhh finally',
#  'aaahhmazing chicken',
#  'aaahing food',
#  'aaahing mmmmming',
#  'aaaiiight doubt',
#  'aaaj main',
#  'aaallll night',
#  'aaalright apps',
#  'aaamazing fav',
#  'aaamazing huge',
#  'aaamazing little',
#  'aaamazing note',
#  'aaamazing reviews',
#  'aaamazing salad',
#  'aaamazing salads',
#  'aaamazing server',
#  'aaamazing worth',
#  'aaammmazzzzzingg best',
#  'aaand blue',
#  'aaand came',
#  'aaand cost',
#  'aaand flick',
#  'aaand food',
#  'aaand gave',
#  'aaand got',
#  'aaand ice',
#  'aaand nothing',
#  'aaand pineapple',
#  'aaannd favorites',
#  'aaannnd free',
#  'aaannnd pretty',
#  'aaannnd scene',
#  'aaannndd burritos',
#  'aaannyway rishnaa',
#  'aaanyway circled',
#  'aaanyways food',
#  'aaargh understand',
#  'aaarrgghhh food',
#  'aaarrgh whoever',
#  'aaarrrrrrrr lot',
#  'aaauuggh thank',
#  'aaawooga wolf',
#  'aaawww indicate',
#  'aabb org',
#  'aabdwfcuyb daee',
#  'aabout dogs',
#  'aac golden',
#  'aac roll',
#  'aachar white',
#  'aachari paneer',
#  'aack bang',
#  'aack location',
#  'aacu womens',
#  'aadd one',
#  'aadvantage status',
#  'aafter waiting',
#  'aah ask',
#  'aah charged',
#  'aah could',
#  'aah demetre',
#  'aah ing',
#  'aah lahore',
#  'aah lot',
#  'aah moment',
#  'aah one',
#  ...]

# %% [markdown]
# # 3.  TF-IDF Model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tv = TfidfVectorizer(min_df=0., max_df=1., use_idf=True)
tv_matrix = tv.fit_transform(norm_corpus)
# tv_matrix = tv_matrix.toarray()

vocab = tv.get_feature_names()
# pd.DataFrame(np.round(tv_matrix, 2), columns=vocab)

# %%
vocab
# Out:
# ['__',
#  '___',
#  '____',
#  '_____',
#  '______',
#  '_______',
#  '________',
#  '_________',
#  '__________',
#  '___________',
#  '____________',
#  '_____________',
#  '______________',
#  '_______________',
#  '________________',
#  '_________________',
#  '__________________',
#  '___________________',
#  '____________________',
#  '_____________________',
#  '______________________',
#  '_______________________',
#  '________________________',
#  '_________________________',
#  '__________________________',
#  '___________________________',
#  '____________________________',
#  '_____________________________',
#  '______________________________',
#  '_______________________________',
#  '________________________________',
#  '_________________________________',
#  '__________________________________',
#  '_____________________________________',
#  '_______________________________________',
#  '________________________________________',
#  '__________________________________________',
#  '___________________________________________',
#  '____________________________________________',
#  '______________________________________________',
#  '_______________________________________________',
#  '_________________________________________________',
#  '__________________________________________________',
#  '___________________________________________________',
#  '____________________________________________________',
#  '_____________________________________________________',
#  '______________________________________________________',
#  '_________________________________________________________',
#  '__________________________________________________________',
#  '___________________________________________________________',
#  '_____________________________________________________________',
#  '______________________________________________________________',
#  '_______________________________________________________________',
#  '________________________________________________________________',
#  '_________________________________________________________________',
#  '___________________________________________________________________',
#  '_____________________________________________________________________',
#  '________________________________________________________________________',
#  '__________________________________________________________________________',
#  '_________________________________________________________________________________',
#  '__________________________________________________________________________________',
#  '_________the',
#  '_____atmosphere',
#  '_____food',
#  '_____overall',
#  '_____service',
#  '____the',
#  '___day',
#  '___n',
#  '___when',
#  '__bus',
#  '__lsa',
#  '__ngt__',
#  '__notary',
#  '__o',
#  '__sometypeoffish__',
#  '_a',
#  '_ages_',
#  '_all',
#  '_anderson',
#  '_any_',
#  '_are_',
#  '_bad_',
#  '_barely_',
#  '_big_',
#  '_box_',
#  '_c',
#  '_ca',
#  '_ce',
#  '_cheap_',
#  '_cheese',
#  '_chooses_',
#  '_consistently_',
#  '_cq',
#  '_dargs',
#  '_data',
#  '_definitely_',
#  '_does_',
#  '_douhua_',
#  '_down_',
#  '_duarte',
#  '_eeff_b',
#  '_eiycbz',
#  '_en',
#  '_excellent_',
#  '_expensive_',
#  '_extremely_',
#  '_fbe',
#  '_felt_',
#  '_feng',
#  '_good_',
#  '_gravy_',
#  '_i',
#  '_i_',
#  '_interesting_',
#  '_is_',
#  '_just_',
#  '_kajananc',
#  '_kings',
#  '_krwakwmt',
#  '_ksklafvkwihygspopa',
#  '_last',
#  '_less_',
#  '_like_',
#  '_long_',
#  '_luudmk',
#  '_mattgranger',
#  '_my_',
#  '_mzdlwm',
#  '_news_and_community',
#  '_nice',
#  '_not_',
#  '_now',
#  '_o',
#  '_of',
#  '_on_',
#  '_only_',
#  '_or_',
#  '_ouzjmtcwrftadfhajq',
#  '_parklawn_rd',
#  '_pear',
#  '_picked',
#  '_places_to_get_filipino',
#  '_proper_',
#  '_qnncmfw',
#  '_quite_',
#  '_r',
#  '_really_',
#  '_restaurant',
#  '_rrbbjlgug',
#  '_second',
#  '_seriously_',
#  '_she_',
#  '_shit',
#  '_shocked_',
#  '_some_',
#  '_ssoirhw',
#  '_steakqueenagain',
#  '_stop',
#  '_terrible_',
#  '_that_',
#  '_the',
#  '_the_',
#  '_the_best_',
#  '_themselves',
#  '_they_',
#  '_think_',
#  '_thinks_',
#  '_tiny_',
#  '_too_',
#  '_tqrhjha',
#  '_ttpeyg',
#  '_twice_',
#  '_unhealthy_',
#  '_unique_',
#  '_us',
#  '_very_',
#  '_was',
#  '_wasn',
#  '_will_',
#  '_without',
#  '_won',
#  '_work_',
#  '_xkcnn',
#  '_years_',
#  '_youtiao_',
#  'a_s',
#  'aa',
#  'aaa',
#  'aaaa',
#  'aaaaa',
#  'aaaaaaa',
#  'aaaaaaaaa',
#  'aaaaaaaaaaaa',
#  'aaaaaaaaaaaaaaaaaaaaaaagesss',
#  'aaaaaaaaaaaaaasking',
#  'aaaaaaaaaaaanddd',
#  'aaaaaaaaaaamazing',
#  'aaaaaaaaamazing',
#  'aaaaaaaaand',
#  'aaaaaaaamazing',
#  'aaaaaaaannnnd',
#  'aaaaaaaas',
#  'aaaaaaah',
#  'aaaaaaahhh',
#  'aaaaaaahhhhh',
#  'aaaaaaalll',
#  'aaaaaaamazing',
#  'aaaaaaand',
#  'aaaaaaarrrrrrgggggg',
#  'aaaaaah',
#  'aaaaaall',
#  'aaaaaallllll',
#  'aaaaaamaaaaaziiiiing',
#  'aaaaaamazing',
#  'aaaaaand',
#  'aaaaaare',
#  'aaaaaaribaaa',
#  'aaaaages',
#  'aaaaah',
#  'aaaaahhh',
#  'aaaaahhhhh',
#  'aaaaahhhhhh',
#  'aaaaahs',
#  'aaaaall',
#  'aaaaalll',
#  'aaaaalllll',
#  'aaaaamaazing',
#  'aaaaamazing',
#  'aaaaammmmaaazzzziiinnnggggg',
#  'aaaaamzzzing',
#  'aaaaand',
#  'aaaaandd',
#  'aaaaannnnd',
#  'aaaaannnndddd',
#  'aaaaanyway',
#  'aaaaarrrrgh',
#  'aaaaat',
#  'aaaaawww',
#  'aaaaddlggyaaaaaaqngfq',
#  'aaaadorable',
#  'aaaages',
#  'aaaaggges',
#  'aaaah',
#  'aaaahh',
#  'aaaahhh',
#  'aaaahhhs',
#  'aaaahing',
#  'aaaahs',
#  'aaaaight',
#  'aaaall',
#  'aaaalll',
#  'aaaallllll',
#  'aaaalways',
#  'aaaamazing',
#  'aaaammmmmaaazing',
#  'aaaand',
#  'aaaannnd',
#  'aaaannndd',
#  'aaaanyhow',
#  'aaaanyway',
#  'aaaare',
#  'aaaarrrggghhh',
#  'aaaarrrrrrrrrggggggggghhh',
#  'aaaas',
#  'aaaasss',
#  'aaaat',
#  'aaaawesome',
#  'aaaazing',
#  'aaac',
#  'aaack',
#  'aaaf',
#  'aaagrills',
#  'aaah',
#  'aaahalalsteaks',
#  'aaahed',
#  'aaahh',
#  'aaahhh',
#  'aaahhhh',
#  'aaahhhhh',
#  'aaahhmazing',
#  'aaahing',
#  'aaaiiight',
#  'aaaj',
#  'aaallll',
#  'aaalright',
#  'aaamazing',
#  'aaammmazzzzzingg',
#  'aaand',
#  'aaannd',
#  'aaannnd',
#  'aaannndd',
#  'aaannyway',
#  'aaanyway',
#  'aaanyways',
#  'aaargh',
#  'aaarrgghhh',
#  'aaarrgh',
#  'aaarrrrrrrr',
#  'aaauuggh',
#  'aaawooga',
#  'aaawww',
#  'aabb',
#  'aabdwfcuyb',
#  'aabout',
#  'aac',
#  'aachar',
#  'aachari',
#  'aack',
#  'aacu',
#  'aadd',
#  'aadvantage',
#  'aafter',
#  'aah',
#  'aaha',
#  'aahed',
#  'aahh',
#  'aahhh',
#  'aahhhh',
#  'aahhhhhhmaazing',
#  'aahhmaazing',
#  'aahhs',
#  'aahing',
#  'aahs',
#  'aahwy',
#  'aai',
#  'aaiden',
#  'aaiiyaaa',
#  'aak',
#  'aakash',
#  'aaked',
#  'aakriti',
#  'aakritis',
#  'aal',
#  'aalitle',
#  'aaliyah',
#  'aalo',
#  'aaloo',
#  'aalwa',
#  'aalways',
#  'aam',
#  'aamaazing',
#  'aamazing',
#  'aamir',
#  'aamlate',
#  'aammaazziinngg',
#  'aammmamaazing',
#  'aammmmaaazing',
#  'aamna',
#  'aamzinnnggggg',
#  'aan',
#  'aanach',
#  'aanch',
#  'aand',
#  'aanddd',
#  'aano',
#  'aanrader',
#  'aap',
#  'aapam',
#  'aardvark',
#  'aargh',
#  'aarif',
#  'aaron',
#  'aaron_eats_',
#  'aarons',
#  'aaroport',
#  'aaround',
#  'aarp',
#  'aarre',
#  'aarrgg',
#  'aarrggh',
#  'aarrgghh',
#  'aarti',
#  'aas',
#  'aash',
#  'aat',
#  'aatendent',
#  'aauce',
#  'aaucy',
#  'aawash',
#  'aawww',
#  'aawwwhhhhssssooooooemmm',
#  'aay',
#  'aaya',
#  'aayy',
#  'aaí',
#  'ab',
#  'aba',
#  'ababa',
#  'ababe',
#  'abacaxi',
#  'aback',
#  'abackk',
#  'abacus',
#  'abadabo',
#  'abadir',
#  'abadirs',
#  'abag',
#  'abah',
#  'abai',
#  'abailable',
#  'abaixo',
#  'abalone',
#  'abalonelive',
#  'abalones',
#  'abandon',
#  'abandoned',
#  'abandonedlooking',
#  'abandoning',
#  'abandonment',
#  'abandonned',
#  'abandons',
#  'abandunce',
#  'abao',
#  'abaricious',
#  'abarkcrombie',
#  'abarth',
#  'abas',
#  'abashedly',
#  'abashiri',
#  'abassi',
#  'abate',
#  'abated',
#  'abatement',
#  'abates',
#  'abattage',
#  'abattoir',
#  'abawi',
#  'abb',
#  'abba',
#  'abbaba',
#  'abbabiatta',
#  'abbamania',
#  'abbas',
#  'abbasi',
#  'abbass',
#  'abbasy',
#  'abbatoir',
#  'abbaye',
#  'abbazia',
#  'abbeakndbhb_ihlxqchaq',
#  'abberation',
#  'abbey',
#  'abbeygrand',
#  'abbeys',
#  'abbeyskitchen',
#  'abbi',
#  'abbiamo',
#  'abbirami',
#  'abble',
#  'abbot',
#  'abbots',
#  'abbotsford',
#  'abbott',
#  'abbottking',
#  'abboud',
#  'abbout',
#  'abbrasive',
#  'abbreviate',
#  'abbreviated',
#  'abbreviation',
#  'abbreviations',
#  'abbriterti',
#  'abbruo',
#  'abbruzo',
#  'abbruzzino',
#  'abbruzzos',
#  'abburi',
#  'abburri',
#  'abby',
#  'abc',
#  'abcd',
#  'abcdefghijk',
#  'abcess',
#  'abck',
#  'abcoasters',
#  'abcs',
#  'abd',
#  'abdel',
#  'abderrahman',
#  'abdest',
#  'abdeuklfsxxogxgpig',
#  'abdicate',
#  'abdicated',
#  'abdicating',
#  'abdin',
#  'abdo',
#  'abdolute',
#  'abdomen',
#  'abdomin',
#  'abdominal',
#  'abdominals',
#  'abdonminal',
#  'abduct',
#  'abducted',
#  'abduction',
#  'abductor',
#  'abdul',
#  'abdula',
#  'abdulaziz',
#  'abdule',
#  'abdulla',
#  'abdullah',
#  'abdullas',
#  'abdundant',
#  'abdurahman',
#  'abe',
#  'abebooks',
#  'abec',
#  'abed',
#  'abedi',
#  'abejas',
#  'abel',
#  'abell',
#  'abelled',
#  'abenaro',
#  'abend',
#  'abende',
#  'abendessen',
#  'abends',
#  'abendsonne',
#  'abendveranstaltungen',
#  'aber',
#  'aberage',
#  'aberation',
#  'abercombie',
#  'abercrombie',
#  'aberdeen',
#  'aberino',
#  'aberrant',
#  'aberration',
#  'aberrations',
#  'aberta',
#  'abesent',
#  'abet',
#  'abeurk',
#  'abex',
#  'abexp',
#  'abeyance',
#  'abf',
#  'abfab',
#  'abfahrt',
#  'abfertiung',
#  'abflug',
#  'abgedeckt',
#  'abgefllt',
#  'abgelegte',
#  'abgepackte',
#  'abgesehen',
#  'abgetrennten',
#  'abgewohnt',
#  'abgoosht',
#  'abgosht',
#  'abhi',
#  'abhishek',
#  'abholung',
#  'abhor',
#  'abhore',
#  'abhorently',
#  'abhorration',
#  'abhorred',
#  'abhorrence',
#  'abhorrent',
#  'abhorrently',
#  'abhorring',
#  'abhors',
#  'abhyangas',
#  'abi',
#  'abiance',
#  'abiayion',
#  'abicurious',
#  'abid',
#  'abidance',
#  'abide',
#  'abided',
#  'abides',
#  'abiding',
#  'abience',
#  'abient',
#  'abig',
#  'abigail',
#  'abiid',
#  'abilites',
#  'abilities',
#  'ability',
#  'abilty',
#  'abiocco',
#  'abir',
#  'abiration',
#  'abismal',
#  'abit',
#  'abiteast',
#  'abitibi',
#  'abiut',
#  'abive',
#  'abject',
#  'abjectly',
#  'abke',
#  'abkrzung',
#  'ablahan',
#  'ablaze',
#  'able',
#  'ablebodied',
#  'abled',
#  'ableism',
#  'ableist',
#  'ables',
#  'ableto',
#  'ableton',
#  'abliged',
#  'abloy',
#  'ablution',
#  'ablutions',
#  'ably',
#  'abm',
#  'abmience',
#  'abms',
#  'abnormal',
#  'abnormalities',
#  'abnormality',
#  'abnormally',
#  'abnormaly',
#  'abnoxious',
#  'aboard',
#  'aboauletly',
#  'abobado',
#  'abobe',
#  'abodabo',
#  'abode',
#  'abodo',
#  'abogado',
#  'abogee',
#  'aboit',
#  'aboiut',
#  'abolished',
#  'abolishing',
#  'abolsute',
#  'abolsutely',
#  'abolutely',
#  'abominable',
#  'abominably',
#  'abominal',
#  'abomination',
#  'abominations',
#  'abomonation',
#  'abondance',
#  'abondante',
#  'abondanza',
#  'abonded',
#  'abonne',
#  'abonnement',
#  'abooking',
#  'abooration',
#  'aboot',
#  'abooth',
#  'abord',
#  'abordable',
#  'abordables',
#  'abore',
#  'aboriginal',
#  'aboriginalinspired',
#  'aboriginally',
#  'aboriginals',
#  'aborio',
#  'abort',
#  'aborted',
#  'aborting',
#  'abortion',
#  'abortions',
#  'abos',
#  'aboslute',
#  'aboslutely',
#  'abosolutely',
#  'abosoluty',
#  'abosultly',
#  'abot',
#  'abott',
#  'abotts',
#  'abotu',
#  'abou',
#  'aboua',
#  'aboue',
#  'abound',
#  'abounded',
#  'abounding',
#  'abounds',
#  'abour',
#  'abousolity',
#  'aboustle',
#  'about',
#  'about_four_seasons',
#  'about_skymiles',
#  'about_us',
#  'abouta',
#  'abouti',
#  'aboutnorth',
#  'abouts',
#  'aboutthe',
#  'aboutus',
#  'aboutwhere',
#  'aboutyourhood',
#  'abouuut',
#  'abouve',
#  'abouy',
#  'above',
#  'aboveall',
#  'aboveandbeyond',
#  'aboveaverage',
#  'aboveaverge',
#  'abovegroud',
#  'aboveground',
#  'abovemediocre',
#  'abovementioned',
#  'abover',
#  'aboves',
#  'aboút',
#  'abput',
#  'abr',
#  'abra',
#  'abracadabra',
#  'abraconyc',
#  'abrading',
#  'abraham',
#  'abrahams',
#  'abram',
#  'abramov',
#  'abramovitch',
#  'abrams',
#  'abrand',
#  'abras',
#  'abrasian',
#  'abrasion',
#  'abrasions',
#  'abrasive',
#  'abrasively',
#  'abrcrombie',
#  'abreast',
#  'abreise',
#  'abreisetag',
#  'abri',
#  'abricot',
#  'abridged',
#  'abrigada',
#  'abrigo',
#  'abriram',
#  'abris',
#  'abrió',
#  'abroad',
#  'abroise',
#  'abrosia',
#  'abrubt',
#  'abrubtly',
#  'abrui',
#  'abrump',
#  'abrupt',
#  'abruption',
#  'abruptly',
#  'abruptness',
#  'abruri',
#  'abrushi',
#  'abrutly',
#  'abruzio',
#  'abruzza',
#  'abruzzese',
#  'abruzzi',
#  'abruzzo',
#  'abruzzo_pizza',
#  'abruzzopizza',
#  'abruzzopizza_flyer_',
#  'abruzzos',
#  'abs',
#  'absaultly',
#  'abscess',
#  'abscessed',
#  'abscesses',
#  'abscond',
#  'absconded',
#  'absence',
#  'absences',
#  'absent',
#  'absente',
#  'absentee',
#  'absentia',
#  'absently',
#  'absentminded',
#  'absentmindedly',
#  'absentmindedness',
#  'absents',
#  'absentvacant',
#  'absewnce',
#  'absi',
#  'absilutely',
#  'absinth',
#  'absinthe',
#  'absinthophile',
#  'absinths',
#  'absintini',
#  'absloutely',
#  'abso',
#  'absofavourite',
#  'absofricking',
#  'absofrickinlutely',
#  'absofuckinglutely',
#  'absolotely',
#  'absolotuley',
#  'absoloute',
#  'absoloutely',
#  'absoloutley',
#  'absoloutly',
#  'absoltely',
#  'absoltuely',
#  'absoluely',
#  'absoluetly',
#  'absoluety',
#  'absolulely',
#  'absolultely',
#  'absolulutely',
#  'absolument',
#  'absolut',
#  'absolute',
#  'absoluteeeee',
#  'absolutele',
#  'absolutelllllyyyy',
#  'absolutelly',
#  'absolutelty',
#  'absolutelu',
#  'absolutely',
#  'absolutelya',
#  'absolutelyloved',
#  'absolutelyyy',
#  'absolutes',
#  'absolutest',
#  'absolutetly',
#  'absolutey',
#  'absolution',
#  'absolutism',
#  'absolutist',
#  'absolutlely',
#  'absolutlety',
#  'absolutley',
#  'absolutly',
#  'absoluty',
#  'absoluuuuuutttteeellly',
#  'absoluyely',
#  'absolve',
#  'absolved',
#  'absolves',
#  'absorb',
#  'absorbancy',
#  'absorbatent',
#  'absorbed',
#  'absorbency',
#  'absorbent',
#  'absorber',
#  'absorbers',
#  'absorbing',
#  'absorbs',
#  'absorbtion',
#  'absorption',
#  'absouitely',
#  'absoulety',
#  'absoultely',
#  'absoultey',
#  'absoultly',
#  'absoulutely',
#  'absoutely',
#  'abssoulti',
#  'abssynia',
#  'abstain',
#  'abstained',
#  'abstaining',
#  'abstains',
#  'abstand',
#  'abstecher',
#  'abstinence',
#  'abstolutely',
#  'abstract',
#  'abstracted',
#  'abstracts',
#  'absulote',
#  'absulutely',
#  'absurb',
#  'absurd',
#  'absurdia',
#  'absurdity',
#  'absurdly',
#  'absymal',
#  'absynthe',
#  'abt',
#  'abtasted',
#  'abtd',
#  'abteer',
#  'abteilen',
#  'abteilungen',
#  'abu',
#  'abudance',
#  'abudnance',
#  'abuela',
#  'abuelas',
#  'abuelita',
#  'abulahea',
#  'abulsute',
#  'abunch',
#  'abundace',
#  'abundance',
#  'abundances',
#  'abundancy',
#  'abundandant',
#  'abundant',
#  'abundante',
#  'abundantly',
#  'abundence',
#  'abundent',
#  'abundunt',
#  'abunga',
#  'abuot',
#  'abura',
#  'aburaage',
#  'aburai',
#  'abure',
#  'aburi',
#  'aburicious',
#  'aburis',
#  'aburiscious',
#  'aburistyle',
#  'aburisushi',
#  'aburitorched',
#  'aburo',
#  'aburri',
#  'aburuchio',
#  'aburusicios',
#  'abus',
#  'abusable',
#  'abuse',
#  'abused',
#  'abuser',
#  'abusers',
#  'abuses',
#  'abusing',
#  'abusive',
#  'abusively',
#  'abusiveness',
#  'abusivo',
#  'abusolutely',
#  'abut',
#  'abuts',
#  'abutted',
#  'abutting',
#  'abuzz',
#  'abv',
#  'abvious',
#  'abviously',
#  'abwandlungen',
#  'abwechlungsreiche',
#  'abwechslung',
#  'abwheel',
#  'abwinken',
#  'aby',
#  'abyone',
#  'abys',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'abyssal',
#  'abyssinia',
#  'abyssinian',
#  'abyssinians',
#  'abyssmal',
#  'abything',
#  'abzug',
#  'ac',
#  'ac_apg',
#  'acabado',
#  'acabamos',
#  'acacado',
#  'acacia',
#  'acacias',
#  'academese',
#  'academia',
#  'academic',
#  'academically',
#  'academics',
#  'academies',
#  'academy',
#  'academyinstitute',
#  'academystudent',
#  'acadey',
#  'acadia',
#  'acadian',
#  'acadians',
#  'acadomy',
#  'acafrao',
#  'acai',
#  'acaibowl',
#  'acaii',
#  'acana',
#  'acanac',
#  'acanacs',
#  'acandfurnace',
#  'acapella',
#  ...]

# %% [markdown]
# The TF-IDF based feature vectors for each of our text documents show scaled and normalized values as compared to the raw Bag of Words model values.
